# %% [markdown]
# Train Test Split

# %%
import pandas as pd

df = pd.read_csv("./Datasets/airport.csv")

# %%
df
# Out:
#          id    ident           type  \
# 0     26555     VIDP  large_airport
# 1     26434     VABB  large_airport
# 2     26618     VOMM  large_airport
# 3     35145     VOBL  large_airport
# 4     26444     VAGO  large_airport
# ..      ...      ...            ...
# 332   46625  IN-0062  small_airport
# 333   46640  IN-0064  small_airport
# 334   46561  IN-0038       heliport
# 335  319166  IN-0101  small_airport
# 336   46557  IN-0034  small_airport
#
#                                           name  latitude_deg  longitude_deg  \
# 0          Indira Gandhi International Airport     28.566500      77.103104
# 1    Chhatrapati Shivaji International Airport     19.088699      72.867897
# 2                Chennai International Airport     12.990005      80.169296
# 3             Kempegowda International Airport     13.197900      77.706299
# 4                    Goa International Airport     15.380800      73.831398
# ..                                         ...           ...            ...
# 332                            Shirpur Airport     21.323999      74.956734
# 333                           Umaria Air Field     23.532514      80.808220
# 334           Upper Tadong Indian Army Helipad     27.306717      88.599650
# 335                         Vanasthali Airport     26.407627      75.870128
# 336                        Vijay Nagar Airport     19.884100      73.840567
#
#      elevation_ft iso_region   municipality  scheduled_service gps_code  \
# 0           777.0      IN-DL      New Delhi                  1     VIDP
# 1            39.0      IN-MM         Mumbai                  1     VABB
# 2            52.0      IN-TN        Chennai                  1     VOMM
# 3          3000.0      IN-KA      Bangalore                  1     VOBL
# 4           150.0      IN-GA  Vasco da Gama                  1     VOGO
# ..            ...        ...            ...                ...      ...
# 332           NaN      IN-MM        Shirpur                  0      NaN
# 333        1510.0      IN-MP         Umaria                  0      NaN
# 334           NaN      IN-SK   Upper Tadong                  0      NaN
# 335           NaN      IN-RJ     Vanasthali                  0      NaN
# 336           NaN      IN-MM    Vijay Nagar                  0      NaN
#
#     iata_code local_code  year_built  year_tier Closed  \
# 0         DEL        NaN      1930.0     1950.0      n
# 1         BOM        NaN      1942.0     1950.0      n
# 2         MAA        NaN      1910.0     1950.0      n
# 3         BLR        NaN      2008.0     2010.0      n
# 4         GOI        NaN      1955.0     1955.0      n
# ..        ...        ...         ...        ...    ...
# 332       NaN        NaN         NaN        NaN      n
# 333       NaN        NaN         NaN        NaN      n
# 334       NaN        NaN         NaN        NaN      n
# 335       NaN        NaN         NaN        NaN      n
# 336       NaN        NaN         NaN        NaN      n
#
#                                           home_link  \
# 0                    http://www.newdelhiairport.in/
# 1                               http://www.csia.in/
# 2                                               NaN
# 3    http://www.bengaluruairport.com/home/home.jspx
# 4                                               NaN
# ..                                              ...
# 332                                             NaN
# 333                                             NaN
# 334                                             NaN
# 335                                             NaN
# 336                                             NaN
#
#                                         wikipedia_link  \
# 0    http://en.wikipedia.org/wiki/Indira_Gandhi_Int...
# 1    http://en.wikipedia.org/wiki/Chhatrapati_Shiva...
# 2    http://en.wikipedia.org/wiki/Chennai_Internati...
# 3    https://en.wikipedia.org/wiki/Kempegowda_Inter...
# 4         http://en.wikipedia.org/wiki/Dabolim_Airport
# ..                                                 ...
# 332                                                NaN
# 333                                                NaN
# 334                                                NaN
# 335                                                NaN
# 336                                                NaN
#
#                                               keywords    score
# 0                              Palam Air Force Station    51475
# 1                  Bombay, Sahar International Airport  1014475
# 2                                                  NaN    51150
# 3                                                  NaN    51200
# 4    Goa Airport, Dabolim Navy Airbase, ________隷怄_...      875
# ..                                                 ...      ...
# 332                                     Shirpur, Dhule        0
# 333                                                NaN        0
# 334                                                NaN        0
# 335                                                NaN        0
# 336                                                NaN        0
#
# [337 rows x 20 columns]

# %%
from sklearn.model_selection import train_test_split
X = df.iloc[0:,:19]
print(X)
# Out:
#          id    ident           type  \
# 0     26555     VIDP  large_airport
# 1     26434     VABB  large_airport
# 2     26618     VOMM  large_airport
# 3     35145     VOBL  large_airport
# 4     26444     VAGO  large_airport
# ..      ...      ...            ...
# 332   46625  IN-0062  small_airport
# 333   46640  IN-0064  small_airport
# 334   46561  IN-0038       heliport
# 335  319166  IN-0101  small_airport
# 336   46557  IN-0034  small_airport
#
#                                           name  latitude_deg  longitude_deg  \
# 0          Indira Gandhi International Airport     28.566500      77.103104
# 1    Chhatrapati Shivaji International Airport     19.088699      72.867897
# 2                Chennai International Airport     12.990005      80.169296
# 3             Kempegowda International Airport     13.197900      77.706299
# 4                    Goa International Airport     15.380800      73.831398
# ..                                         ...           ...            ...
# 332                            Shirpur Airport     21.323999      74.956734
# 333                           Umaria Air Field     23.532514      80.808220
# 334           Upper Tadong Indian Army Helipad     27.306717      88.599650
# 335                         Vanasthali Airport     26.407627      75.870128
# 336                        Vijay Nagar Airport     19.884100      73.840567
#
#      elevation_ft iso_region   municipality  scheduled_service gps_code  \
# 0           777.0      IN-DL      New Delhi                  1     VIDP
# 1            39.0      IN-MM         Mumbai                  1     VABB
# 2            52.0      IN-TN        Chennai                  1     VOMM
# 3          3000.0      IN-KA      Bangalore                  1     VOBL
# 4           150.0      IN-GA  Vasco da Gama                  1     VOGO
# ..            ...        ...            ...                ...      ...
# 332           NaN      IN-MM        Shirpur                  0      NaN
# 333        1510.0      IN-MP         Umaria                  0      NaN
# 334           NaN      IN-SK   Upper Tadong                  0      NaN
# 335           NaN      IN-RJ     Vanasthali                  0      NaN
# 336           NaN      IN-MM    Vijay Nagar                  0      NaN
#
#     iata_code local_code  year_built  year_tier Closed  \
# 0         DEL        NaN      1930.0     1950.0      n
# 1         BOM        NaN      1942.0     1950.0      n
# 2         MAA        NaN      1910.0     1950.0      n
# 3         BLR        NaN      2008.0     2010.0      n
# 4         GOI        NaN      1955.0     1955.0      n
# ..        ...        ...         ...        ...    ...
# 332       NaN        NaN         NaN        NaN      n
# 333       NaN        NaN         NaN        NaN      n
# 334       NaN        NaN         NaN        NaN      n
# 335       NaN        NaN         NaN        NaN      n
# 336       NaN        NaN         NaN        NaN      n
#
#                                           home_link  \
# 0                    http://www.newdelhiairport.in/
# 1                               http://www.csia.in/
# 2                                               NaN
# 3    http://www.bengaluruairport.com/home/home.jspx
# 4                                               NaN
# ..                                              ...
# 332                                             NaN
# 333                                             NaN
# 334                                             NaN
# 335                                             NaN
# 336                                             NaN
#
#                                         wikipedia_link  \
# 0    http://en.wikipedia.org/wiki/Indira_Gandhi_Int...
# 1    http://en.wikipedia.org/wiki/Chhatrapati_Shiva...
# 2    http://en.wikipedia.org/wiki/Chennai_Internati...
# 3    https://en.wikipedia.org/wiki/Kempegowda_Inter...
# 4         http://en.wikipedia.org/wiki/Dabolim_Airport
# ..                                                 ...
# 332                                                NaN
# 333                                                NaN
# 334                                                NaN
# 335                                                NaN
# 336                                                NaN
#
#                                               keywords
# 0                              Palam Air Force Station
# 1                  Bombay, Sahar International Airport
# 2                                                  NaN
# 3                                                  NaN
# 4    Goa Airport, Dabolim Navy Airbase, ________隷怄_...
# ..                                                 ...
# 332                                     Shirpur, Dhule
# 333                                                NaN
# 334                                                NaN
# 335                                                NaN
# 336                                                NaN
#
# [337 rows x 19 columns]
# 0        51475
# 1      1014475
# 2        51150
# 3        51200
# 4          875
#         ...
# 332          0
# 333          0
# 334          0
# 335          0
# 336          0
# Name: score, Length: 337, dtype: int64

# %%
Y = df.iloc[:,-1]
print(Y)
# Out:
# 0        51475
# 1      1014475
# 2        51150
# 3        51200
# 4          875
#         ...
# 332          0
# 333          0
# 334          0
# 335          0
# 336          0
# Name: score, Length: 337, dtype: int64

# %%
X_train,X_test,Y_train, Y_test = train_test_split(X,Y,random_state=0 , train_size = .80)

# %%
print(X_train , X_test , Y_train , Y_test)
# Out:
#         id    ident            type  \
# 17   26501     VEGT  medium_airport
# 219  31691     VEKW   small_airport
# 92   26574     VIRB   small_airport
# 278  46628  IN-0063          closed
# 191   3306  IN-VA74   small_airport
# ..     ...      ...             ...
# 323  46606  IN-0054          closed
# 192   3324     VI43   small_airport
# 117  26558     VIGR  medium_airport
# 47   26489     VEAT  medium_airport
# 172   3284     VA1C   small_airport
#
#                                                  name  latitude_deg  \
# 17   Lokpriya Gopinath Bordoloi International Airport     26.106100
# 219                                    Khowai Airport     24.061899
# 92                                 Fursatganj Airport     26.248501
# 278                               Cholavaram Airstrip     13.210242
# 191                                  Abu Road Airport     24.494200
# ..                                                ...           ...
# 323                                   Charra Airfield     23.365777
# 192                             Suratgarh New Airport     29.387800
# 117                                   Gwalior Airport     26.293301
# 47                                   Agartala Airport     23.886999
# 172                                 Birlagram Airport     23.446899
#
#      longitude_deg  elevation_ft iso_region municipality  scheduled_service  \
# 17       91.585899         162.0      IN-AS     Guwahati                  1
# 219      91.603897          95.0      IN-TR       Khowai                  0
# 92       81.380501         360.0      IN-UP          NaN                  0
# 278      80.152345           NaN      IN-TN          NaN                  0
# 191      72.781502         875.0      IN-RJ          NaN                  0
# ..             ...           ...        ...          ...                ...
# 323      86.436739           NaN      IN-WB      Purulia                  0
# 192      73.903900         554.0      IN-RJ          NaN                  0
# 117      78.227798         617.0      IN-MP      Gwalior                  1
# 47       91.240402          46.0      IN-TR     Agartala                  1
# 172      75.420303        1541.0      IN-MP          NaN                  0
#
#     gps_code iata_code local_code  year_built  year_tier Closed  \
# 17      VEGT       GAU        NaN      1958.0     1960.0      n
# 219     VEKW       IXN        NaN         NaN        NaN      y
# 92      VIRB       NaN        NaN         NaN        NaN      n
# 278      NaN       NaN        NaN         NaN        NaN      y
# 191     VA74       NaN       VA74         NaN        NaN      n
# ..       ...       ...        ...         ...        ...    ...
# 323      NaN       NaN        NaN         NaN        NaN      y
# 192     VI43       NaN       VI43         NaN        NaN      n
# 117     VIGR       GWL        NaN         NaN        NaN      n
# 47      VEAT       IXA        NaN      1942.0     1950.0      n
# 172     VA1C       NaN       VA1C         NaN        NaN      n
#
#                               home_link  \
# 17   http://aai.aero/guwahati/index.jsp
# 219                                 NaN
# 92                                  NaN
# 278                                 NaN
# 191                                 NaN
# ..                                  ...
# 323                                 NaN
# 192                                 NaN
# 117                                 NaN
# 47                                  NaN
# 172                                 NaN
#
#                                         wikipedia_link  \
# 17   http://en.wikipedia.org/wiki/Lokpriya_Gopinath...
# 219                                                NaN
# 92                                                 NaN
# 278                                                NaN
# 191                                                NaN
# ..                                                 ...
# 323       http://en.wikipedia.org/wiki/Charra_Airfield
# 192                                                NaN
# 117       http://en.wikipedia.org/wiki/Gwalior_Airport
# 47       http://en.wikipedia.org/wiki/Agartala_Airport
# 172                                                NaN
#
#                                               keywords
# 17   Borjhar Airport, Mountain Shadow Air Force Sta...
# 219                                                NaN
# 92                                                 NaN
# 278                                                NaN
# 191                                                NaN
# ..                                                 ...
# 323                                                NaN
# 192                          Phalodi Air Force Station
# 117                       Maharajpur Air Force Station
# 47      Singerbhil Airport, Agartala Air Force Station
# 172                                                NaN
#
# [269 rows x 19 columns]          id    ident            type                        name  \
# 54    26546     VIBR  medium_airport        Kullu Manali Airport
# 52    26627     VOTP   small_airport            Tirupati Airport
# 275   42721  IN-0005          closed           Kayathar Airstrip
# 271  308280  IN-0084          closed                      Salwas
# 199   30005     VEKM   small_airport            Kamalpur Airport
# ..      ...      ...             ...                         ...
# 64    26554     VIDN  medium_airport            Dehradun Airport
# 100  301051  IN-0074   small_airport     Barbil Aerodrome (JSPL)
# 173    3287     VA1F   small_airport               Sidhi Airport
# 12    26455     VAPO  medium_airport  Pune International Airport
# 264   46551  IN-0028        heliport              Pukpui Helipad
#
#      latitude_deg  longitude_deg  elevation_ft iso_region municipality  \
# 54      31.876699      77.154404        3573.0      IN-HP          NaN
# 52      13.632500      79.543297         350.0      IN-AP     Tirupati
# 275      8.971389      77.820625           NaN      IN-TN          NaN
# 271     26.141647      73.097062           NaN      IN-RJ          NaN
# 199     24.131701      91.814201         131.0      IN-TR          NaN
# ..            ...            ...           ...        ...          ...
# 64      30.189699      78.180298        1831.0      IN-UP     Dehradun
# 100     22.048614      85.374194           NaN      IN-OR          NaN
# 173     24.402300      81.814796        1093.0      IN-MP          NaN
# 12      18.582100      73.919701        1942.0      IN-MM         Pune
# 264     22.942267      92.768850           NaN      IN-MZ          NaN
#
#      scheduled_service gps_code iata_code local_code  year_built  year_tier  \
# 54                   0     VIBR       KUU        NaN      1950.0     1950.0
# 52                   1     VOTP       TIR        NaN      1976.0     1980.0
# 275                  0      NaN       NaN        NaN         NaN        NaN
# 271                  0      NaN       NaN        NaN         NaN        NaN
# 199                  0     VEKM       IXQ        NaN         NaN        NaN
# ..                 ...      ...       ...        ...         ...        ...
# 64                   1     VIDN       DED        NaN      1974.0     1975.0
# 100                  0      NaN       NaN        NaN         NaN        NaN
# 173                  0     VA1F       NaN       VA1F         NaN        NaN
# 12                   1     VAPO       PNQ        NaN      1939.0     1950.0
# 264                  0      NaN       NaN        NaN         NaN        NaN
#
#     Closed                                          home_link  \
# 54       n                                                NaN
# 52       n  http://aai.aero/allAirports/tirupati_generalin...
# 275      y                                                NaN
# 271      y                                                NaN
# 199      n                                                NaN
# ..     ...                                                ...
# 64       n  http://aai.aero/allAirports/dehradun_generalin...
# 100      n                                                NaN
# 173      n                                                NaN
# 12       n                                                NaN
# 264      n                                                NaN
#
#                                        wikipedia_link  \
# 54                                                NaN
# 52      http://en.wikipedia.org/wiki/Tirupati_Airport
# 275                                               NaN
# 271                                               NaN
# 199                                               NaN
# ..                                                ...
# 64   http://en.wikipedia.org/wiki/Jolly_Grant_Airport
# 100                                               NaN
# 173                                               NaN
# 12          http://en.wikipedia.org/wiki/Pune_Airport
# 264                                               NaN
#
#                                          keywords
# 54                                            NaN
# 52                                            NaN
# 275                                           NaN
# 271                                           NaN
# 199                                           NaN
# ..                                            ...
# 64                                            NaN
# 100                                           NaN
# 173                                           NaN
# 12   Lohegaon Airport, Lohegaon Air Force Station
# 264                               Lunglei,helipad
#
# [68 rows x 19 columns] 17     925
# 219     50
# 92      50
# 278      0
# 191     50
#       ...
# 323      0
# 192     50
# 117    800
# 47     800
# 172     50
# Name: score, Length: 269, dtype: int64 54     250
# 52     450
# 275      0
# 271      0
# 199     50
#       ...
# 64     800
# 100      0
# 173     50
# 12     800
# 264      0
# Name: score, Length: 68, dtype: int64
