# %%
import gensim.downloader as api
we = api.load("word2vec-google-news-300")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
we.similarity("good" , "better")
# Out:
# 0.6120728

# %%
we.most_similar("dogs")
# Out:
# [('dog', 0.8680490851402283),
#  ('canines', 0.8181711435317993),
#  ('cats', 0.7651764154434204),
#  ('pit_bulls', 0.7548302412033081),
#  ('pets', 0.7424417734146118),
#  ('puppies', 0.7385991811752319),
#  ('pooches', 0.7162365913391113),
#  ('German_shepherds', 0.707106351852417),
#  ('animals', 0.6985694766044617),
#  ('pit_bull', 0.6983614563941956)]

# %%
we.doesnt_match(["dog" , "cat" , "lion" , "elon"])
# Out:
# 'lion'

# %%
# France - Paris + Berlin = Germany

# %%
we.most_similar(positive = ["France" , "Berlin"], negative = ["Paris"])
# Out:
# [('Germany', 0.7901254892349243),
#  ('Austria', 0.6026812195777893),
#  ('German', 0.6004959940910339),
#  ('Germans', 0.5851002931594849),
#  ('Poland', 0.5847075581550598),
#  ('Hungary', 0.5271855592727661),
#  ('BBC_Tristana_Moore', 0.5249711275100708),
#  ('symbol_RSTI', 0.5245768427848816),
#  ('Belgium', 0.5221248269081116),
#  ('Germnay', 0.5199405550956726)]

# %%
we["good"]
# Out:
# array([ 0.04052734,  0.0625    , -0.01745605,  0.07861328,  0.03271484,
#        -0.01263428,  0.00964355,  0.12353516, -0.02148438,  0.15234375,
#        -0.05834961, -0.10644531,  0.02124023,  0.13574219, -0.13183594,
#         0.17675781,  0.27148438,  0.13769531, -0.17382812, -0.14160156,
#        -0.03076172,  0.19628906, -0.03295898,  0.125     ,  0.25390625,
#         0.12695312, -0.15234375,  0.03198242,  0.01135254, -0.01361084,
#        -0.12890625,  0.01019287,  0.23925781, -0.08447266,  0.140625  ,
#         0.13085938, -0.04516602,  0.06494141,  0.02539062,  0.05615234,
#         0.24609375, -0.20507812,  0.23632812, -0.00860596, -0.02294922,
#         0.05078125,  0.10644531, -0.03564453,  0.08740234, -0.05712891,
#         0.08496094,  0.23535156, -0.10107422, -0.03564453, -0.04736328,
#         0.04736328, -0.14550781, -0.10986328,  0.14746094, -0.23242188,
#        -0.07275391,  0.19628906, -0.37890625, -0.07226562,  0.04833984,
# ...
